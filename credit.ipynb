# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
appdf = pd.read_csv('application_record.csv')
appdf.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %% [markdown]
# ### shape of the dataset

# %%
appdf.shape
# Out:
# (438557, 18)

# %% [markdown]
# ### columns names

# %%
appdf.keys()
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %% [markdown]
# ### Non-Null Count and DType of the columns

# %%
appdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %% [markdown]
# ### Description of the non-object columns

# %%
appdf.describe().T
# Out:
#                      count          mean            std        min        25%  \
# ID                438557.0  6.022176e+06  571637.023257  5008804.0  5609375.0
# CNT_CHILDREN      438557.0  4.273903e-01       0.724882        0.0        0.0
# AMT_INCOME_TOTAL  438557.0  1.875243e+05  110086.853066    26100.0   121500.0
# DAYS_BIRTH        438557.0 -1.599790e+04    4185.030007   -25201.0   -19483.0
# DAYS_EMPLOYED     438557.0  6.056368e+04  138767.799647   -17531.0    -3103.0
# FLAG_MOBIL        438557.0  1.000000e+00       0.000000        1.0        1.0
# FLAG_WORK_PHONE   438557.0  2.061328e-01       0.404527        0.0        0.0
# FLAG_PHONE        438557.0  2.877710e-01       0.452724        0.0        0.0
# FLAG_EMAIL        438557.0  1.082071e-01       0.310642        0.0        0.0
# CNT_FAM_MEMBERS   438557.0  2.194465e+00       0.897207        1.0        2.0
#
#                         50%        75%        max
# ID                6047745.0  6456971.0  7999952.0
# ...

# %% [markdown]
# ### No. of unique values in each column

# %%
appdf.nunique()
# Out:
# ID                     438510
# CODE_GENDER                 2
# FLAG_OWN_CAR                2
# FLAG_OWN_REALTY             2
# CNT_CHILDREN               12
# AMT_INCOME_TOTAL          866
# NAME_INCOME_TYPE            5
# NAME_EDUCATION_TYPE         5
# NAME_FAMILY_STATUS          5
# NAME_HOUSING_TYPE           6
# DAYS_BIRTH              16379
# DAYS_EMPLOYED            9406
# FLAG_MOBIL                  1
# FLAG_WORK_PHONE             2
# FLAG_PHONE                  2
# FLAG_EMAIL                  2
# OCCUPATION_TYPE            18
# CNT_FAM_MEMBERS            13
# dtype: int64

# %% [markdown]
# ### No. of NULL values in each column

# %%
appdf.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
appdf.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Importing credit record dataset

# %%
creditdf = pd.read_csv('credit_record.csv')
creditdf.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
# shape
creditdf.shape
# Out:
# (1048575, 3)

# %%
# columns name
creditdf.keys()
# Out:
# Index(['ID', 'MONTHS_BALANCE', 'STATUS'], dtype='object')

# %%
# info
creditdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
# describe
creditdf.describe()
# Out:
#                  ID  MONTHS_BALANCE
# count  1.048575e+06    1.048575e+06
# mean   5.068286e+06   -1.913700e+01
# std    4.615058e+04    1.402350e+01
# min    5.001711e+06   -6.000000e+01
# 25%    5.023644e+06   -2.900000e+01
# 50%    5.062104e+06   -1.700000e+01
# 75%    5.113856e+06   -7.000000e+00
# max    5.150487e+06    0.000000e+00

# %%
# no. of unique values in each col
creditdf.nunique()
# Out:
# ID                45985
# MONTHS_BALANCE       61
# STATUS                8
# dtype: int64

# %%
# no. of null values in each col
creditdf.isnull().sum()
# Out:
# ID                0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64

# %%
creditdf.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Application Records Count Plots

# %%
def countplot_appdf(app_features, app_hue):
    for app_feature in app_features:
        
        plt.figure(figsize = (12, 12))
        ax = sns.countplot(y = appdf[app_feature], hue = app_hue , data = appdf)
        plt.legend(loc = 'best')
        n = len(appdf[app_feature])
        
        for bar in ax.patches:
            percentage = '{:.2f}%'.format(100 * bar.get_width()/n)
            x = bar.get_x() + bar.get_width() + 0.05
            y = bar.get_y() + bar.get_height()/2
            ax.annotate(percentage, (x, y))
    plt.show()
    
app_features = []
for column in appdf.columns:
    if (appdf[column].dtype == 'object'):
        app_features.append(column)

countplot_appdf(app_features, 'CODE_GENDER')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_808\3011839389.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc = 'best')

# %% [markdown]
# ## Credit Records Count Plot

# %%
def countplot_creditdf(credit_features):
    for credit_feature in credit_features:
        
        plt.figure(figsize = (12, 12))
        ax = sns.countplot(y = creditdf[credit_feature], data = creditdf)
        n = len(creditdf[credit_feature])
        
        for bar in ax.patches:
            percentage = '{:.2f}%'.format(100 * bar.get_width()/n)
            x = bar.get_x() + bar.get_width() + 0.05
            y = bar.get_y() + bar.get_height()/2
            ax.annotate(percentage, (x, y))
    plt.show()
    
credit_features = []
for column in creditdf.columns:
    if (creditdf[column].dtype == 'object'):
        credit_features.append(column)

countplot_creditdf(credit_features)

# %% [markdown]
# ## BOX plot for numerical cols

# %%
import matplotlib.pyplot as plt

num_cols = appdf.select_dtypes(include='number')
plt.figure(figsize=(14,6))
num_cols.boxplot()
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection in Numerical Features")
plt.show()

# %%
import matplotlib.pyplot as plt

num_cols = appdf.select_dtypes(include='number')

# Remove binary and ID columns
num_cols = num_cols.drop(columns=[
    'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'ID'
])

plt.figure(figsize=(12, 10))

for i, col in enumerate(num_cols.columns, 1):
    plt.subplot(2, 3, i)
    plt.boxplot(num_cols[col])   # vertical by default
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Application Record Dataset

# %%
# insert age column and drop days_birth
age = []

for i in range(0, len(appdf)):
    res = (abs(appdf['DAYS_BIRTH'][i]) // 365.25)
    age.append(res)

# %%
appdf.insert(11,'AGE', age)
appdf.drop(['DAYS_BIRTH'], axis = 1, inplace = True)

# %%
appdf.loc[(appdf['DAYS_EMPLOYED'] > 0), 'DAYS_EMPLOYED'] = 0

# %%
employed_years = []

for j in range(0, len(appdf)):
    res1 = (abs(appdf['DAYS_EMPLOYED'][j]) // 365.25)
    employed_years.append(res1)

# %%
appdf.insert(13,'EMPLOYED_YEARS', employed_years)
appdf.drop(['DAYS_EMPLOYED'], axis = 1, inplace = True)

# %%
# drop duplicates ids
appdf.drop_duplicates(subset = ['ID'], inplace=True)

# %%
# remove flag_mobil column
appdf.drop(['FLAG_MOBIL'], axis = 1, inplace=True)

# %%
appdf.drop(['FLAG_PHONE'], axis = 1, inplace=True)

# %%
appdf.drop(['FLAG_EMAIL'], axis = 1, inplace=True)

# %%
appdf.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# ...

# %%
appdf.shape
# Out:
# (438510, 15)

# %%
### filling NAN values in 'OCCUPATION_TYPE' column
appdf['OCCUPATION_TYPE'].fillna(value = 'Occupation Not Identified', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_808\19570135.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   appdf['OCCUPATION_TYPE'].fillna(value = 'Occupation Not Identified', inplace=True)

# %%
# mentioning 'OCCUPATION_TYPE' as 'Retired' of those having 'NAME_INCOME_TYPE' as 'pensioner'
appdf.loc[(appdf['NAME_INCOME_TYPE'] == 'Pensioner') & (appdf['OCCUPATION_TYPE'] == 'Occupation Not Identified'), 'OCCUPATION_TYPE'] = 'Retired'

# %%
appdf.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# ...

# %% [markdown]
# ### credit dataset

# %%
creditdf[['ID', 'MONTHS_BALANCE']].drop_duplicates()
# Out:
#               ID  MONTHS_BALANCE
# 0        5001711               0
# 1        5001711              -1
# 2        5001711              -2
# 3        5001711              -3
# 4        5001712               0
# ...          ...             ...
# 1048570  5150487             -25
# 1048571  5150487             -26
# 1048572  5150487             -27
# 1048573  5150487             -28
# 1048574  5150487             -29
#
# [1048575 rows x 2 columns]

# %%
convert_to = {'C' : 'Good_Debt', 'X' : 'Good_Debt', '0' : 'Good_Debt', '1' : 'Neutral_Debt', '2' : 'Neutral_Debt', '3' : 'Bad_Debt', '4' : 'Bad_Debt', '5' : 'Bad_Debt'}
creditdf.replace({'STATUS' : convert_to}, inplace = True) 

creditdf
# Out:
#               ID  MONTHS_BALANCE     STATUS
# 0        5001711               0  Good_Debt
# 1        5001711              -1  Good_Debt
# 2        5001711              -2  Good_Debt
# 3        5001711              -3  Good_Debt
# 4        5001712               0  Good_Debt
# ...          ...             ...        ...
# 1048570  5150487             -25  Good_Debt
# 1048571  5150487             -26  Good_Debt
# 1048572  5150487             -27  Good_Debt
# 1048573  5150487             -28  Good_Debt
# 1048574  5150487             -29  Good_Debt
#
# [1048575 rows x 3 columns]

# %%
creditdf = creditdf.value_counts(subset = ['ID', 'STATUS']).unstack(fill_value = 0)
creditdf
# Out:
# STATUS   Bad_Debt  Good_Debt  Neutral_Debt
# ID
# 5001711         0          4             0
# 5001712         0         19             0
# 5001713         0         22             0
# 5001714         0         15             0
# 5001715         0         60             0
# ...           ...        ...           ...
# 5150482         0         18             0
# 5150483         0         18             0
# 5150484         0         13             0
# 5150485         0          2             0
# 5150487         0         30             0
#
# [45985 rows x 3 columns]

# %%
print(creditdf.columns)
# Out:
# Index(['Bad_Debt', 'Good_Debt', 'Neutral_Debt'], dtype='object', name='STATUS')

# %%
creditdf.loc[(creditdf['Good_Debt'] > creditdf['Neutral_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 1
creditdf.loc[(creditdf['Good_Debt'] > creditdf['Bad_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 1
creditdf.loc[(creditdf['Neutral_Debt'] > creditdf['Bad_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 1
creditdf.loc[(creditdf['Neutral_Debt'] > creditdf['Good_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 0
creditdf.loc[(creditdf['Bad_Debt'] > creditdf['Good_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 0
creditdf.loc[(creditdf['Bad_Debt'] > creditdf['Neutral_Debt']), 'CREDIT_CARD_APPROVAL_STATUS'] = 0

# %%
creditdf['CREDIT_CARD_APPROVAL_STATUS'] = creditdf['CREDIT_CARD_APPROVAL_STATUS'].astype('int')
creditdf
# Out:
# STATUS   Bad_Debt  Good_Debt  Neutral_Debt  CREDIT_CARD_APPROVAL_STATUS
# ID
# 5001711         0          4             0                            1
# 5001712         0         19             0                            1
# 5001713         0         22             0                            1
# 5001714         0         15             0                            1
# 5001715         0         60             0                            1
# ...           ...        ...           ...                          ...
# 5150482         0         18             0                            1
# 5150483         0         18             0                            1
# 5150484         0         13             0                            1
# 5150485         0          2             0                            1
# 5150487         0         30             0                            1
#
# [45985 rows x 4 columns]

# %%
creditdf.drop(['Bad_Debt', 'Good_Debt', 'Neutral_Debt'], axis = 1, inplace = True)
creditdf
# Out:
# STATUS   CREDIT_CARD_APPROVAL_STATUS
# ID
# 5001711                            1
# 5001712                            1
# 5001713                            1
# 5001714                            1
# 5001715                            1
# ...                              ...
# 5150482                            1
# 5150483                            1
# 5150484                            1
# 5150485                            1
# 5150487                            1
#
# [45985 rows x 1 columns]

# %%
creditdf['CREDIT_CARD_APPROVAL_STATUS'].value_counts()
# Out:
# CREDIT_CARD_APPROVAL_STATUS
# 1    45726
# 0      259
# Name: count, dtype: int64

# %%
appdf.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# remane 'CODE_GENDER' column into 'GENDER'
appdf.rename(columns={"CODE_GENDER" : "GENDER"}, inplace=True)

# %%
appdf['GENDER'].value_counts()
# Out:
# GENDER
# F    294406
# M    144104
# Name: count, dtype: int64

# %%
# encoding
le = LabelEncoder()
appdf['GENDER'] = le.fit_transform(appdf['GENDER'])

# %%
appdf.head()
# Out:
#         ID  GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804       1            Y               Y             0
# 1  5008805       1            Y               Y             0
# 2  5008806       1            Y               Y             0
# 3  5008808       0            N               Y             0
# 4  5008809       0            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# 0        Civil marriage   Rented apartment  32.0            12.0
# ...

# %%
# encoding flag_own_car column 

appdf['FLAG_OWN_CAR'] = le.fit_transform(appdf['FLAG_OWN_CAR'])

# %%
# changing 'FLAG_OWN_CAR' column name into 'FLAG_OWN_CAR' 
appdf.rename(columns={"FLAG_OWN_CAR" : "OWN_CAR"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0  5008804       1        1               Y             0          427500.0
# 1  5008805       1        1               Y             0          427500.0
# 2  5008806       1        1               Y             0          112500.0
# 3  5008808       0        0               Y             0          270000.0
# 4  5008809       0        0               Y             0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
# ...

# %%
appdf['FLAG_OWN_REALTY'].value_counts()
# Out:
# FLAG_OWN_REALTY
# Y    304040
# N    134470
# Name: count, dtype: int64

# %%
# encoding flag_own_realty column
appdf['FLAG_OWN_REALTY'] = le.fit_transform(appdf['FLAG_OWN_REALTY'])

# %%
# changing 'FLAG_OWN_REALTY' column name into 'OWN_REALTY' 
appdf.rename(columns={"FLAG_OWN_REALTY" : "OWN_REALTY"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0  5008804       1        1           1             0          427500.0
# 1  5008805       1        1           1             0          427500.0
# 2  5008806       1        1           1             0          112500.0
# 3  5008808       0        0           1             0          270000.0
# 4  5008809       0        0           1             0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#    NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  FLAG_WORK_PHONE  \
# ...

# %%
# changing 'CNT_CHILDREN' column name into 'CHILDREN' 
appdf.rename(columns={"CNT_CHILDREN" : "CHILDREN"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  AMT_INCOME_TOTAL  \
# 0  5008804       1        1           1         0          427500.0
# 1  5008805       1        1           1         0          427500.0
# 2  5008806       1        1           1         0          112500.0
# 3  5008808       0        0           1         0          270000.0
# 4  5008809       0        0           1         0          270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#    NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  FLAG_WORK_PHONE  \
# ...

# %%
# changing 'AMT_INCOME_TOTAL' column name into 'TOTAL_INCOME' 
appdf.rename(columns={"AMT_INCOME_TOTAL" : "TOTAL_INCOME"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  \
# 0  5008804       1        1           1         0      427500.0
# 1  5008805       1        1           1         0      427500.0
# 2  5008806       1        1           1         0      112500.0
# 3  5008808       0        0           1         0      270000.0
# 4  5008809       0        0           1         0      270000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#    NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  FLAG_WORK_PHONE  \
# ...

# %%
appdf['NAME_INCOME_TYPE'].value_counts()
# Out:
# NAME_INCOME_TYPE
# Working                 226076
# Commercial associate    100744
# Pensioner                75488
# State servant            36185
# Student                     17
# Name: count, dtype: int64

# %%
# encoding name_income_type
appdf['NAME_INCOME_TYPE'] = le.fit_transform(appdf['NAME_INCOME_TYPE'])

# %%
# changing 'NAME_INCOME_TYPE' column name into 'INCOME_TYPE' 
appdf.rename(columns={"NAME_INCOME_TYPE" : "INCOME_TYPE"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0               Higher education        Civil marriage   Rented apartment
# 1               Higher education        Civil marriage   Rented apartment
# 2  Secondary / secondary special               Married  House / apartment
# 3  Secondary / secondary special  Single / not married  House / apartment
# 4  Secondary / secondary special  Single / not married  House / apartment
#
# ...

# %%
appdf['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# NAME_EDUCATION_TYPE
# Secondary / secondary special    301788
# Higher education                 117512
# Incomplete higher                 14847
# Lower secondary                    4051
# Academic degree                     312
# Name: count, dtype: int64

# %%
# encoding NAME_EDUCATION_TYPE column
appdf['NAME_EDUCATION_TYPE'] = le.fit_transform(appdf['NAME_EDUCATION_TYPE'])

# %%
appdf.rename(columns={"NAME_EDUCATION_TYPE" : "EDUCATION_TYPE"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  \
# 0               1        Civil marriage   Rented apartment  32.0
# 1               1        Civil marriage   Rented apartment  32.0
# 2               4               Married  House / apartment  58.0
# 3               4  Single / not married  House / apartment  52.0
# 4               4  Single / not married  House / apartment  52.0
#
#    EMPLOYED_YEARS  FLAG_WORK_PHONE            OCCUPATION_TYPE  CNT_FAM_MEMBERS
# ...

# %%
appdf['NAME_FAMILY_STATUS'].value_counts()
# Out:
# NAME_FAMILY_STATUS
# Married                 299798
# Single / not married     55258
# Civil marriage           36529
# Separated                27251
# Widow                    19674
# Name: count, dtype: int64

# %%
appdf['NAME_FAMILY_STATUS'] = le.fit_transform(appdf['NAME_FAMILY_STATUS'])

# %%
appdf.rename(columns={"NAME_FAMILY_STATUS" : "FAMILY_STATUS"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE  FAMILY_STATUS  NAME_HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# 0               1              0   Rented apartment  32.0            12.0
# 1               1              0   Rented apartment  32.0            12.0
# 2               4              1  House / apartment  58.0             3.0
# 3               4              3  House / apartment  52.0             8.0
# 4               4              3  House / apartment  52.0             8.0
#
# ...

# %%
appdf['NAME_HOUSING_TYPE'].value_counts()
# Out:
# NAME_HOUSING_TYPE
# House / apartment      393791
# With parents            19075
# Municipal apartment     14212
# Rented apartment         5973
# Office apartment         3920
# Co-op apartment          1539
# Name: count, dtype: int64

# %%
# encoding NAME_HOUSING_TYPE column
appdf['NAME_HOUSING_TYPE'] = le.fit_transform(appdf['NAME_HOUSING_TYPE'])

# %%
appdf.rename(columns={"NAME_HOUSING_TYPE" : "HOUSING_TYPE"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  EMPLOYED_YEARS  \
# 0               1              0             4  32.0            12.0
# 1               1              0             4  32.0            12.0
# 2               4              1             1  58.0             3.0
# 3               4              3             1  52.0             8.0
# 4               4              3             1  52.0             8.0
#
#    FLAG_WORK_PHONE            OCCUPATION_TYPE  CNT_FAM_MEMBERS
# ...

# %%
# changing 'EMPLOYED_YEARS' column name into 'EXPERIENCE' 
appdf.rename(columns={"EMPLOYED_YEARS" : "EXPERIENCE"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  EXPERIENCE  \
# 0               1              0             4  32.0        12.0
# 1               1              0             4  32.0        12.0
# 2               4              1             1  58.0         3.0
# 3               4              3             1  52.0         8.0
# 4               4              3             1  52.0         8.0
#
#    FLAG_WORK_PHONE            OCCUPATION_TYPE  CNT_FAM_MEMBERS
# ...

# %%
# changing 'CFLAG_WORK_PHONE' column name into 'WORK_PHONE' 
appdf.rename(columns={"FLAG_WORK_PHONE" : "WORK_PHONE"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  EXPERIENCE  WORK_PHONE  \
# 0               1              0             4  32.0        12.0           1
# 1               1              0             4  32.0        12.0           1
# 2               4              1             1  58.0         3.0           0
# 3               4              3             1  52.0         8.0           0
# 4               4              3             1  52.0         8.0           0
#
# ...

# %%
appdf['OCCUPATION_TYPE'].value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                     78231
# Retired                      75352
# Occupation Not Identified    58841
# Core staff                   43000
# Sales staff                  41094
# Managers                     35481
# Drivers                      26090
# High skill tech staff        17285
# Accountants                  15983
# Medicine staff               13518
# Cooking staff                 8076
# Security staff                7993
# Cleaning staff                5843
# Private service staff         3455
# Low-skill Laborers            2140
# Secretaries                   2044
# Waiters/barmen staff          1665
# Realty agents                 1041
# HR staff                       774
# IT staff                       604
# Name: count, dtype: int64

# %%
# encoding OCCUPATION_TYPE column
appdf['OCCUPATION_TYPE'] = le.fit_transform(appdf['OCCUPATION_TYPE'])

# %%
# changing 'CNT_FAM_MEMBERS' column name into 'FAM_MEMBERS' 
appdf.rename(columns={"CNT_FAM_MEMBERS" : "FAM_MEMBERS"}, inplace=True)
appdf.head()
# Out:
#         ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  INCOME_TYPE  \
# 0  5008804       1        1           1         0      427500.0            4
# 1  5008805       1        1           1         0      427500.0            4
# 2  5008806       1        1           1         0      112500.0            4
# 3  5008808       0        0           1         0      270000.0            0
# 4  5008809       0        0           1         0      270000.0            0
#
#    EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  EXPERIENCE  WORK_PHONE  \
# 0               1              0             4  32.0        12.0           1
# 1               1              0             4  32.0        12.0           1
# 2               4              1             1  58.0         3.0           0
# 3               4              3             1  52.0         8.0           0
# 4               4              3             1  52.0         8.0           0
#
#    OCCUPATION_TYPE  FAM_MEMBERS
# ...

# %%
appdf
# Out:
#              ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  \
# 0       5008804       1        1           1         0      427500.0
# 1       5008805       1        1           1         0      427500.0
# 2       5008806       1        1           1         0      112500.0
# 3       5008808       0        0           1         0      270000.0
# 4       5008809       0        0           1         0      270000.0
# ...         ...     ...      ...         ...       ...           ...
# 438552  6840104       1        0           1         0      135000.0
# 438553  6840222       0        0           0         0      103500.0
# 438554  6841878       0        0           0         0       54000.0
# 438555  6842765       0        0           1         0       72000.0
# 438556  6842885       0        0           1         0      121500.0
#
#         INCOME_TYPE  EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  \
# ...

# %%
creditdf
# Out:
# STATUS   CREDIT_CARD_APPROVAL_STATUS
# ID
# 5001711                            1
# 5001712                            1
# 5001713                            1
# 5001714                            1
# 5001715                            1
# ...                              ...
# 5150482                            1
# 5150483                            1
# 5150484                            1
# 5150485                            1
# 5150487                            1
#
# [45985 rows x 1 columns]

# %% [markdown]
# ## merged both datasets

# %%
# merge both  datasets
merged_df = appdf.reset_index().merge(creditdf, on = 'ID').set_index('index')
merged_df
# Out:
#              ID  GENDER  OWN_CAR  OWN_REALTY  CHILDREN  TOTAL_INCOME  \
# index
# 0       5008804       1        1           1         0      427500.0
# 1       5008805       1        1           1         0      427500.0
# 2       5008806       1        1           1         0      112500.0
# 3       5008808       0        0           1         0      270000.0
# 4       5008809       0        0           1         0      270000.0
# ...         ...     ...      ...         ...       ...           ...
# 434808  5149828       1        1           1         0      315000.0
# 434809  5149834       0        0           1         0      157500.0
# 434810  5149838       0        0           1         0      157500.0
# 434811  5150049       0        0           1         0      283500.0
# 434812  5150337       1        0           1         0      112500.0
#
#         INCOME_TYPE  EDUCATION_TYPE  FAMILY_STATUS  HOUSING_TYPE   AGE  \
# index
# ...

# %% [markdown]
# ### Save merged_df as a .csv file

# %%
merged_df.to_csv('Merged_Dataset.csv')

# %%
# columns name
merged_df.keys()
# Out:
# Index(['ID', 'GENDER', 'OWN_CAR', 'OWN_REALTY', 'CHILDREN', 'TOTAL_INCOME',
#        'INCOME_TYPE', 'EDUCATION_TYPE', 'FAMILY_STATUS', 'HOUSING_TYPE', 'AGE',
#        'EXPERIENCE', 'WORK_PHONE', 'OCCUPATION_TYPE', 'FAM_MEMBERS',
#        'CREDIT_CARD_APPROVAL_STATUS'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36457 entries, 0 to 434812
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           36457 non-null  int64
#  1   GENDER                       36457 non-null  int64
#  2   OWN_CAR                      36457 non-null  int64
#  3   OWN_REALTY                   36457 non-null  int64
#  4   CHILDREN                     36457 non-null  int64
#  5   TOTAL_INCOME                 36457 non-null  float64
#  6   INCOME_TYPE                  36457 non-null  int64
#  7   EDUCATION_TYPE               36457 non-null  int64
#  8   FAMILY_STATUS                36457 non-null  int64
#  9   HOUSING_TYPE                 36457 non-null  int64
#  10  AGE                          36457 non-null  float64
#  11  EXPERIENCE                   36457 non-null  float64
#  12  WORK_PHONE                   36457 non-null  int64
# ...

# %%
merged_df.describe()
# Out:
#                  ID        GENDER       OWN_CAR    OWN_REALTY      CHILDREN  \
# count  3.645700e+04  36457.000000  36457.000000  36457.000000  36457.000000
# mean   5.078227e+06      0.329895      0.379708      0.672189      0.430315
# std    4.187524e+04      0.470181      0.485321      0.469422      0.742367
# min    5.008804e+06      0.000000      0.000000      0.000000      0.000000
# 25%    5.042028e+06      0.000000      0.000000      0.000000      0.000000
# 50%    5.074614e+06      0.000000      0.000000      1.000000      0.000000
# 75%    5.115396e+06      1.000000      1.000000      1.000000      1.000000
# max    5.150487e+06      1.000000      1.000000      1.000000     19.000000
#
#        TOTAL_INCOME   INCOME_TYPE  EDUCATION_TYPE  FAMILY_STATUS  \
# count  3.645700e+04  36457.000000    36457.000000   36457.000000
# mean   1.866857e+05      2.398195        3.097183       1.367885
# std    1.017892e+05      1.734032        1.341292       0.954557
# ...

# %%
#no. of unique values in each column
merged_df.nunique()
# Out:
# ID                             36457
# GENDER                             2
# OWN_CAR                            2
# OWN_REALTY                         2
# CHILDREN                           9
# TOTAL_INCOME                     265
# INCOME_TYPE                        5
# EDUCATION_TYPE                     5
# FAMILY_STATUS                      5
# HOUSING_TYPE                       6
# AGE                               49
# EXPERIENCE                        44
# WORK_PHONE                         2
# OCCUPATION_TYPE                   20
# FAM_MEMBERS                       10
# CREDIT_CARD_APPROVAL_STATUS        2
# dtype: int64

# %%
# checking null values in each column
merged_df.isnull().sum()
# Out:
# ID                             0
# GENDER                         0
# OWN_CAR                        0
# OWN_REALTY                     0
# CHILDREN                       0
# TOTAL_INCOME                   0
# INCOME_TYPE                    0
# EDUCATION_TYPE                 0
# FAMILY_STATUS                  0
# HOUSING_TYPE                   0
# AGE                            0
# EXPERIENCE                     0
# WORK_PHONE                     0
# OCCUPATION_TYPE                0
# FAM_MEMBERS                    0
# CREDIT_CARD_APPROVAL_STATUS    0
# dtype: int64

# %% [markdown]
# # Splitting Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

# %%
X = merged_df.drop(['ID', 'CREDIT_CARD_APPROVAL_STATUS'], axis=1)
Y = merged_df['CREDIT_CARD_APPROVAL_STATUS']

# %%
#train-test-split
Xtrain, Xtest, Ytrain, Ytest= train_test_split(X, Y, test_size=0.3, random_state=15)

# %%
print("Size of Xtrain Set is:" , len(Xtrain))
print("Size of Xtest Set is:" , len(Xtest))
print("Size of Ytrain Set is:" , len(Ytrain))
print("Size of Ytest Set is:" , len(Ytest))
# Out:
# Size of Xtrain Set is: 25519
# Size of Xtest Set is: 10938
# Size of Ytrain Set is: 25519
# Size of Ytest Set is: 10938

# %%
merged_df['CREDIT_CARD_APPROVAL_STATUS'].value_counts()
# Out:
# CREDIT_CARD_APPROVAL_STATUS
# 1    36221
# 0      236
# Name: count, dtype: int64

# %% [markdown]
# # Importing Custom Decision Tree Classifier That Implemented from Scratch

# %%
from model import DecisionTreeClassifierCustom, Node

# %%
X_train_np = Xtrain.values       # Xtrain is converted into numpy array because it doesnot take a pandas dataframe
y_train_np = Ytrain.values

# %%
custom_tree = DecisionTreeClassifierCustom(max_depth=5, min_samples_split=10)
custom_tree.fit(X_train_np, y_train_np)
# Out:
#   Total nodes created: 51

# %%
X_test_np = Xtest.values
y_pred = custom_tree.predict(X_test_np)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(10938,))

# %% [markdown]
# ### Accuracy

# %%
accuracy = (y_pred == Ytest.values).mean()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9931431705979156

# %%
accuracy = (y_pred == Ytest.values).mean() * 100        # in percentage
print("Accuracy:", accuracy)
# Out:
# Accuracy: 99.31431705979156

# %% [markdown]
# ## constructing a heatmap

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, y_pred)
cm
# Out:
# array([[    0,    72],
#        [    3, 10863]])

# %%
from sklearn.metrics import confusion_matrix

# Predict using trained model
y_pred = custom_tree.predict(Xtest.values)

# Create confusion matrix
cm = confusion_matrix(Ytest, y_pred)

# Plot heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='g', cmap='rocket')

plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.title("Confusion Matrix - Decision Tree")

plt.show()

# %%
TP = 10865 - This means the model successfully approved genuine customers.
FP = 72    - model approved customers who should have been rejected. 
FN = 1     - This means a good customer was wrongly rejected by the model.
TN = 0     - model correctly predicted rejection

# %% [markdown]
# ## importing joblib

# %%
# import joblib

# %%
# # save
# joblib.dump(custom_tree, 'decision_tree.pkl')
# Out:
# ['decision_tree.pkl']

# %%
# load
# dtree=joblib.load('decision_tree.pkl')

# %%
# # predict on first row
# dtree.predict([[1,	1,	1,	0,	427500.0,	4,	1,	0,	4,	32.0,	12.0,	1,	12,	2.0	]])
# Out:
# array([1])

# %%
# Initialize your custom model
# custom_tree = DecisionTreeClassifierCustom(
#     max_depth=5,
#     min_samples_split=10
# )

# # Train the model
# custom_tree.fit(Xtrain, Ytrain)

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
# from sklearn import tree
# #  model fitting
# dectree_model = tree.DecisionTreeClassifier(max_depth=5)
# dectree_model.fit(Xtrain, Ytrain)

# %%
# accuracy
# dectree_model_score = dectree_model.score(Xtest, Ytest)
# dectree_model_score
# Out:
# 0.9933260193819711

# %%
# Out:
# ['decision_tree.pkl']

# %%
# load
dtree=joblib.load('decision_tree.pkl')

# %%
# predict on first row
dtree.predict([[1,	1,	1,	0,	427500.0,	4,	1,	0,	4,	32.0,	12.0,	1,	12,	2.0	]])
# Out:
# d:\credit_card\.env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# predict on 434808 index
dtree.predict([[0,	0,	1,	0,	157500.0,	0, 1,	1,	1,	33.0,	3.0,	0,	11,	2.0	]])
# Out:
# d:\credit_card\.env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ## confusiion metrix

# %%
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## decision Tree

# %%
Y_predicted_dectree = dectree_model.predict(Xtest)
cm = confusion_matrix(Ytest, Y_predicted_dectree)

plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt = 'g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')
